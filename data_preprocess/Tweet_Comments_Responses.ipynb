# %%
pip install openai==0.28

# %%
from google.colab import files
import pandas as pd

# %%
# Import scraped tweets
import pandas as pd

tweet_list = []
length = 0
csv_files = ['Bitcoin.csv', 'NFL.csv', 'Music.csv', 'Oscars.csv', 'Travel.csv', 'Fashion.csv', 'Food.csv', 'Fitness.csv', 'Gaming.csv', 'Art.csv', 'Technology.csv', 'ThrowbackThursday.csv']

for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    length0 = length + 1
    length = len(df) + length
    print(csv_file, length0, length)

    # Extract the 'text' column into a list and extend the text_list
    tweet_list.extend(df['text'].tolist())

print(tweet_list)
len(tweet_list)
# Out:
# Bitcoin.csv 1 440
# NFL.csv 441 945
# Music.csv 946 1090
# Oscars.csv 1091 1608
# Travel.csv 1609 2114
# Fashion.csv 2115 2627
# Food.csv 2628 3133
# Fitness.csv 3134 3324
# Gaming.csv 3325 3836
# Art.csv 3837 4352
# Technology.csv 4353 4856
# ThrowbackThursday.csv 4857 4947
# ...

# %%
# Setup OpenAI API
import openai

# Replace 'YOUR_API_KEY' with your actual API key
openai.api_key = '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'

def generate_response(prompt):
    messages = [
        {"role": "user", "content": prompt}
    ]
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=0.8, # set 0.8 to let the response be more random to some extent
        max_tokens=1024
    )
    response_message = response["choices"][0]["message"]
    response_text = response_message['content']
    num_token = response["usage"]

    return response_text

# %%
# Add the introductory phrase to each tweet in the list
prompts = [f"As you are a user on Twitter. Write a tweet to comment on this Tweet: '{tweet}'" for tweet in tweet_list]

# %%
# Import the saved prompt file
import csv

csv_file = 'prompt.csv'

# Initialize an empty list to store the data from the CSV file
prompts = []

# Open the CSV file and read its contents into the list
with open(csv_file, 'r', newline='') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        prompts.extend(row)


len(prompts)
# Out:
# 4947

# %%
#Import the saved responses file
import csv

csv_file = 'responses.csv'

# Initialize an empty list to store the data from the CSV file
responses = []

# Open the CSV file and read its contents into the list
with open(csv_file, 'r', newline='') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        responses.extend(row)


len(responses)
# Out:
# 4490

# %%
# generate response
#responses = []
#for i in range(405, 4947, 1):
    #group = prompts[i:i + 1]
    #response = [generate_response(prompt) for prompt in group]
    #responses.extend(response)
    #time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     317         while True:
# ...

# %%
# Generate tweet comments for the scraped tweets
import time

# Starting index
start_index = len(responses)

# Total number of prompts
total_prompts = 4947

# Number of prompts to process in each iteration
batch_size = 1

while start_index < total_prompts:
    end_index = min(start_index + batch_size, total_prompts)
    group = prompts[start_index:end_index]

    try:
        response = [generate_response(prompt) for prompt in group]
        responses.extend(response)
        start_index = end_index  # Update the starting index
        time.sleep(5)  # Add a delay between iterations
    except Exception as e:
        print(f"An error occurred: {e}")
        print("Restarting from the last successful response...")
        print(len(responses),start_index,end_index)
        df = pd.DataFrame(responses)
        df.to_csv('responses.csv')
        time.sleep(10)  # Add a delay before restarting
# Out:
# An error occurred: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600)
# Restarting from the last successful response...
# 4498 4498 4499
# An error occurred: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600)
# Restarting from the last successful response...
# 4499 4499 4500
# An error occurred: The server is overloaded or not ready yet.
# Restarting from the last successful response...
# 4506 4506 4507
# An error occurred: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600)
# Restarting from the last successful response...
# 4530 4530 4531
# An error occurred: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600)
# Restarting from the last successful response...
# 4637 4637 4638
# ...

# %%
print(len(responses),start_index,end_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-42735a9ef365> in <cell line: 1>()
# ----> 1 print(len(responses),start_index,end_index)
#
# NameError: name 'responses' is not defined

# %%
# Save the responses file
output_file = 'responses.csv'

with open(output_file, 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write each item in the list as a separate row in the CSV file
    for item in responses:
        csv_writer.writerow([item])

from google.colab import files
files.download("responses.csv")
